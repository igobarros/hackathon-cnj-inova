# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_json('base/justica_eleitoral/processos-tre-ac/processos-tre-ac_1.json')

# %%
df.head(10)
# Out:
#    millisInsercao                                       dadosBasicos  \
# 0   1601915752207  {'assunto': [{'principal': False, 'codigoNacio...
# 1   1601915787787  {'assunto': [{'principal': False, 'codigoNacio...
# 2   1601915785373  {'assunto': [{'principal': False, 'codigoNacio...
# 3   1601915755978  {'assunto': [{'principal': False, 'codigoNacio...
# 4   1601915767014  {'assunto': [{'principal': False, 'codigoNacio...
# 5   1601915767793  {'assunto': [{'principal': False, 'codigoNacio...
# 6   1601915769228  {'assunto': [{'principal': False, 'codigoNacio...
# 7   1601915768934  {'assunto': [{'principal': False, 'codigoNacio...
# 8   1601915772313  {'assunto': [{'principal': False, 'codigoNacio...
# 9   1601915771193  {'assunto': [{'principal': False, 'codigoNacio...
#
#   siglaTribunal                                          movimento grau
# 0        TRE-AC  [{'identificadorMovimento': '399179', 'tipoRes...   G2
# 1        TRE-AC  [{'identificadorMovimento': '422485', 'tipoRes...   G2
# 2        TRE-AC  [{'identificadorMovimento': '425961', 'tipoRes...   G2
# 3        TRE-AC  [{'identificadorMovimento': '400029', 'tipoRes...   G2
# 4        TRE-AC  [{'identificadorMovimento': '400406', 'tipoRes...   G2
# 5        TRE-AC  [{'identificadorMovimento': '400646', 'tipoRes...   G2
# 6        TRE-AC  [{'identificadorMovimento': '400448', 'tipoRes...   G2
# 7        TRE-AC  [{'identificadorMovimento': '400461', 'tipoRes...   G2
# 8        TRE-AC  [{'identificadorMovimento': '423534', 'tipoRes...   G2
# 9        TRE-AC  [{'identificadorMovimento': '424167', 'tipoRes...   G2

# %% [markdown]
# ### Dados Basicos

# %%
dados_basicos = pd.DataFrame([md for md in df.dadosBasicos])

# %%
dados_basicos1 = pd.DataFrame([md for md in dados_basicos.orgaoJulgador])

# %%
dados_basicos2 = pd.DataFrame([md for md in dados_basicos.assunto])

# %%
dados_basicos3 = pd.DataFrame([md for md in dados_basicos2[0]])

# %%
#dados_basicos4 = pd.DataFrame([md for md in dados_basicos2[1]])

# %%
all_json_dadosbasicos = pd.concat([
                            dados_basicos.drop(columns=['assunto', 'orgaoJulgador']), 
                            dados_basicos1, 
                            dados_basicos2.drop(columns=0), 
                            dados_basicos3
], axis=1).reset_index(drop=True)

# %%
all_json_dadosbasicos.head()
# Out:
#   dscSistema  tamanhoProcesso                numero  procEl dataAjuizamento  \
# 0          8               -1  00000258020006010000       2  20000113074300
# 1          8               -1  00001262020006010000       2  20000117085100
# 2          8               -1  00013277620026010000       2  20020502140400
# 3          8               -1  00000537720026010000       2  20020706135900
# 4          8               -1  00002182720026010000       2  20020706172100
#
#    totalAssuntos  classeProcessual  nivelSigilo  competencia codigoLocalidade  \
# 0              1              1298            0            2          1200401
# 1              1             11528            0            2          1200401
# 2              1             11531            0            2          1200401
# 3              1             11532            0            2          1200401
# 4              1             11532            0            2          1200401
#
#                        nomeOrgao  codigoMunicipioIBGE  codigoOrgao instancia  \
# 0          Gabinete do Jurista 2              1200401        78487      ORIG
# 1  Gabinete do Juiz de Direito 1              1200401        78484      ORIG
# 2  Gabinete do Juiz de Direito 1              1200401        78484      ORIG
# 3          Gabinete do Jurista 2              1200401        78487      ORIG
# 4          Gabinete do Jurista 1              1200401        78486      ORIG
#
#       1  principal  codigoNacional
# 0  None      False           11778
# 1  None      False           11778
# 2  None      False           12046
# 3  None      False           12363
# 4  None      False           12363

# %% [markdown]
# ### Movimento

# %%
movimento = pd.DataFrame([md for md in df.movimento])

# %%
movimento1 = pd.DataFrame([md for md in movimento[0]])
movimento1.head(3)
# Out:
#   identificadorMovimento  tipoResponsavelMovimento          movimentoNacional  \
# 0                 399179                         0  {'codigoNacional': 11383}
# 1                 422485                         0  {'codigoNacional': 11383}
# 2                 425961                         0  {'codigoNacional': 11383}
#
#          dataHora                                      orgaoJulgador  \
# 0  20000113074300                                                NaN
# 1  20000208061700                                                NaN
# 2  20020502140400  {'nomeOrgao': 'Gabinete do Vice-Presidente', '...
#
#    tipoDecisao
# 0          NaN
# 1          NaN
# 2          NaN

# %%
movimento2 = pd.DataFrame([md for md in movimento1.movimentoNacional])
movimento2.head(3)
# Out:
#    codigoNacional
# 0           11383
# 1           11383
# 2           11383
