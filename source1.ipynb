# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_json('base/justica_militar/processos-tjmmg/processos-tjmmg_1.json')

# %%
df.head(10)
# Out:
#    millisInsercao                                       dadosBasicos  \
# 0   1573139158136  {'assunto': [{'principal': False, 'codigoNacio...
# 1   1574212187408  {'assunto': [{'principal': False, 'codigoNacio...
# 2   1574207040389  {'assunto': [{'principal': False, 'codigoNacio...
# 3   1572975311600  {'assunto': [{'principal': False, 'codigoNacio...
# 4   1572981416195  {'assunto': [{'principal': False, 'codigoNacio...
# 5   1574207040448  {'assunto': [{'principal': False, 'codigoNacio...
# 6   1556202453808  {'assunto': [{'principal': False, 'codigoNacio...
# 7   1573473438088  {'assunto': [{'principal': False, 'codigoNacio...
# 8   1572979802759  {'assunto': [{'principal': False, 'codigoNacio...
# 9   1572979802836  {'assunto': [{'principal': False, 'codigoNacio...
#
#   siglaTribunal                                          movimento grau
# 0         TJMMG  [{'identificadorMovimento': '1381790', 'movime...   G1
# ...

# %% [markdown]
# ### Dados Basicos

# %%
dados_basicos = pd.DataFrame([md for md in df.dadosBasicos])

# %%
dados_basicos1 = pd.DataFrame([md for md in dados_basicos.orgaoJulgador])

# %%
dados_basicos2 = pd.DataFrame([md for md in dados_basicos.assunto])

# %%
dados_basicos3 = pd.DataFrame([md for md in dados_basicos2[0]])

# %%
#dados_basicos4 = pd.DataFrame([md for md in dados_basicos2[1]])

# %%
all_json_dadosbasicos = pd.concat([
                            dados_basicos.drop(columns=['assunto', 'orgaoJulgador']), 
                            dados_basicos1, 
                            dados_basicos2.drop(columns=0), 
                            dados_basicos3
], axis=1).reset_index(drop=True)

# %%
all_json_dadosbasicos.head()
# Out:
#                  numero  dataAjuizamento  classeProcessual  nivelSigilo  \
# 0  00000025419979130001     855108000000             11553            0
# 1  00000025419979130001     855108000000             11553            0
# 2  00000056619989130003     913860000000             11037            0
# 3  00000056619989130003     913860000000             11037            0
# 4  00000137220009130003     959742000000             11037            0
#
#    competencia codigoLocalidade  valorCausa  tamanhoProcesso  \
# 0          1.0            06200         NaN              NaN
# 1          1.0           310620         NaN              NaN
# 2          1.0           310620         NaN              NaN
# 3          1.0            06200         NaN              NaN
# 4          1.0            06200         NaN              NaN
#
#                                      nomeOrgao  codigoMunicipioIBGE  \
# 0  Primeira Auditoria da Justiça Militar de MG                 6200
# ...

# %%
dados_basicos
# Out:
#                                                 assunto                numero  \
# 0     [{'principal': False, 'codigoNacional': 7940},...  00000025419979130001
# 1     [{'principal': False, 'codigoNacional': 7940},...  00000025419979130001
# 2       [{'principal': False, 'codigoNacional': 11315}]  00000056619989130003
# 3       [{'principal': False, 'codigoNacional': 11315}]  00000056619989130003
# 4     [{'principal': False, 'codigoNacional': 11353}...  00000137220009130003
# ...                                                 ...                   ...
# 1985    [{'principal': False, 'codigoNacional': 10363}]  10000425220169130001
# 1986    [{'principal': False, 'codigoNacional': 11346}]  00010671720169130002
# 1987    [{'principal': False, 'codigoNacional': 11238}]  00010689620169130003
# 1988  [{'principal': False, 'codigoNacional': 11253}...  00010698720169130001
# 1989    [{'principal': False, 'codigoNacional': 11346}]  00010706920169130002
#
# ...

# %% [markdown]
# ### Movimento

# %%
movimento = pd.DataFrame([md for md in df.movimento])

# %%
movimento.head()
# Out:
#                                                    0  \
# 0  {'identificadorMovimento': '1464457', 'movimen...
# 1  {'identificadorMovimento': '1464461', 'movimen...
# 2  {'identificadorMovimento': '996639', 'moviment...
# 3  {'identificadorMovimento': '843803', 'moviment...
# 4  {'identificadorMovimento': '996318', 'moviment...
#
#                                                    1  \
# 0                                               None
# 1                                               None
# 2  {'identificadorMovimento': '997552', 'moviment...
# 3  {'identificadorMovimento': '854220', 'moviment...
# 4  {'identificadorMovimento': '986072', 'moviment...
#
#                                                    2  \
# 0                                               None
# 1                                               None
# 2  {'identificadorMovimento': '1007928', 'movimen...
# 3  {'identificadorMovimento': '919795', 'moviment...
# ...

# %%
movimento1 = pd.DataFrame([md for md in movimento[0]])
movimento1.head(3)
# Out:
#   identificadorMovimento                                     movimentoLocal  \
# 0                1464457  {'codigoMovimento': 1001, 'codigoPaiNacional':...
# 1                1464461  {'codigoMovimento': 1001, 'codigoPaiNacional':...
# 2                 996639  {'codigoMovimento': 1190, 'codigoPaiNacional':...
#
#          dataHora
# 0  20080228000000
# 1  20080228000000
# 2  20110114000000

# %%
movimento2 = pd.DataFrame([md for md in movimento1.movimentoLocal])
movimento2.head(3)
# Out:
#    codigoMovimento  codigoPaiNacional
# 0             1001                 14
# 1             1001                 14
# 2             1190                 14
